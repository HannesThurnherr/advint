# %%
import time
import torch
from torch.utils.data import Dataset, DataLoader, TensorDataset
from torch.optim import Adam
from torch.nn import MSELoss, L1Loss
from SAE import TopKSparseAutoencoder
import transformer_lens
from torch.cuda.amp import autocast

import matplotlib.pyplot as plt
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: numpy in ./myenv/lib/python3.10/site-packages (2.1.2)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
print("packages imported")
# Load a model (eg GPT-2 Small)
model = transformer_lens.HookedTransformer.from_pretrained("tiny-stories-33M")
print("model loaded")

# Check for MPS device
if torch.backends.mps.is_available():
    device = torch.device("mps")
    x = torch.ones(1, device=device)
    print(x)
else:
    device = torch.device("cpu")
    print("MPS device not found. Using CPU.")

model.to(device)
# Out:
# packages imported
# Loaded pretrained model tiny-stories-33M into HookedTransformer
# model loaded
# tensor([1.], device='mps:0')
# Moving model to device:  mps
# HookedTransformer(
#   (embed): Embed()
#   (hook_embed): HookPoint()
#   (pos_embed): PosEmbed()
#   (hook_pos_embed): HookPoint()
#   (blocks): ModuleList(
#     (0-3): 4 x TransformerBlock(
#       (ln1): LayerNormPre(
#         (hook_scale): HookPoint()
#         (hook_normalized): HookPoint()
#       )
#       (ln2): LayerNormPre(
#         (hook_scale): HookPoint()
#         (hook_normalized): HookPoint()
#       )
#       (attn): Attention(
#         (hook_k): HookPoint()
#         (hook_q): HookPoint()
#         (hook_v): HookPoint()
#         (hook_z): HookPoint()
#         (hook_attn_scores): HookPoint()
#         (hook_pattern): HookPoint()
#         (hook_result): HookPoint()
#       )
#       (mlp): MLP(
#         (hook_pre): HookPoint()
#         (hook_post): HookPoint()
#       )
#       (hook_attn_in): HookPoint()
#       (hook_q_input): HookPoint()
#       (hook_k_input): HookPoint()
#       (hook_v_input): HookPoint()
#       (hook_mlp_in): HookPoint()
#       (hook_attn_out): HookPoint()
#       (hook_mlp_out): HookPoint()
#       (hook_resid_pre): HookPoint()
#       (hook_resid_mid): HookPoint()
#       (hook_resid_post): HookPoint()
#     )
#   )
#   (ln_final): LayerNormPre(
#     (hook_scale): HookPoint()
#     (hook_normalized): HookPoint()
#   )
#   (unembed): Unembed()
# )

# %%
# Run the model and get logits and activations
logits, activations = model.run_with_cache(["this", "is", "a", "test"])

activation_key = f'blocks.{2}.hook_resid_post'

print(activations[activation_key].shape)


# Load tokenized data
train_tokens = torch.load('train_tokens.pt')
val_tokens = torch.load('val_tokens.pt')

# Convert tokenized tensors to TensorDataset
train_dataset = TensorDataset(train_tokens['input_ids'], train_tokens['attention_mask'])
val_dataset = TensorDataset(val_tokens['input_ids'], val_tokens['attention_mask'])
# Out:
# torch.Size([4, 2, 768])

# %%
# DataLoader settings
batch_size = 32  # Set your desired batch size
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)


# Define your SAE and training components
latent_dim = 768*2#8192
embedding_dim = 768  # Replace with actual embedding dim from the model


SAE = TopKSparseAutoencoder(input_dim=embedding_dim, latent_dim=latent_dim).to(device)
sae_optimizer = Adam(SAE.parameters(), lr=5e-4)


# Loss functions
mse_loss_fn = MSELoss()
l1_loss_fn = L1Loss()
max_grad_norm = 1.0  # Gradient clipping value

# Training SAE
num_epochs = 1
activation_key = f'blocks.{2}.hook_resid_post'  # Layer 2 residual stream

# %%
sae_losses = []

# %%
# Define hook function to capture activations
activation_key = f'blocks.{2}.hook_resid_post'
activations = None
def activation_hook(module, input, output):
    global activations
    activations = output

# Register hook
hook = model.get_submodule(activation_key).register_forward_hook(activation_hook)

# Training Loop
for epoch in range(num_epochs):
    SAE.train()
    cumulative_sae_recon_loss, cumulative_sae_sparsity_loss = 0, 0

    for batch_idx, (input_ids, attention_mask) in enumerate(train_loader):
        input_ids, attention_mask = input_ids.to(device), attention_mask.to(device)

        sae_optimizer.zero_grad()

        # Model forward pass
        start_time = time.time()
        with torch.no_grad():
            _ = model(input_ids)  # Forward pass to trigger hook
        model_forward_time = time.time() - start_time

        # SAE forward pass
        start_time = time.time()
        with autocast():
            reconstructed, latent = SAE(activations)
            sae_forward_time = time.time() - start_time

            # Loss calculation
            start_time = time.time()
            sae_reconstruction_loss = mse_loss_fn(reconstructed, activations)
            sae_sparsity_loss = l1_loss_fn(latent, torch.zeros_like(latent))
            total_sae_loss = sae_reconstruction_loss
            loss_calc_time = time.time() - start_time
    
            # SAE backward pass
            start_time = time.time()
            total_sae_loss.backward()
            sae_backward_time = time.time() - start_time

            # Gradient clipping and optimizer step
            torch.nn.utils.clip_grad_norm_(SAE.parameters(), max_grad_norm)
            sae_optimizer.step()

        # Track and display batch losses and times
        cumulative_sae_recon_loss += sae_reconstruction_loss.item()
        cumulative_sae_sparsity_loss += sae_sparsity_loss.item()

        print(f"Batch {batch_idx + 1}/{len(train_loader)}: "
              f"Recon Loss={sae_reconstruction_loss.item():.4f}, "
              f"Sparsity Loss={sae_sparsity_loss.item():.4f}, "
              f"Model Forward Time={model_forward_time:.4f}s, "
              f"SAE Forward Time={sae_forward_time:.4f}s, "
              f"Loss Calc Time={loss_calc_time:.4f}s, "
              f"SAE Backward Time={sae_backward_time:.4f}s")
        sae_losses.append(sae_reconstruction_loss.item())
        if batch_idx % 100 == 0:
            plt.plot(sae_losses)
            plt.show()
    # Average epoch losses
    avg_recon_loss = cumulative_sae_recon_loss / len(train_loader)
    avg_sparsity_loss = cumulative_sae_sparsity_loss / len(train_loader)
    print(f"Epoch {epoch + 1}/{num_epochs} - Avg Recon Loss: {avg_recon_loss:.4f}, Avg Sparsity Loss: {avg_sparsity_loss:.4f}")
    
print("SAE Training Complete!")

# Remove hook after training
hook.remove()
# Out:
# Batch 1/66242: Recon Loss=0.5801, Sparsity Loss=0.0252, Model Forward Time=2.2980s, SAE Forward Time=0.0384s, Loss Calc Time=0.0053s, SAE Backward Time=0.0288s
# Batch 2/66242: Recon Loss=0.5601, Sparsity Loss=0.0258, Model Forward Time=0.9307s, SAE Forward Time=0.0378s, Loss Calc Time=0.0046s, SAE Backward Time=0.0342s
# Batch 3/66242: Recon Loss=0.5578, Sparsity Loss=0.0266, Model Forward Time=0.8170s, SAE Forward Time=0.0358s, Loss Calc Time=0.0041s, SAE Backward Time=0.0339s
# Batch 4/66242: Recon Loss=0.5395, Sparsity Loss=0.0282, Model Forward Time=0.2268s, SAE Forward Time=0.0413s, Loss Calc Time=0.0046s, SAE Backward Time=0.0431s
# Batch 5/66242: Recon Loss=0.5341, Sparsity Loss=0.0294, Model Forward Time=0.2023s, SAE Forward Time=0.0389s, Loss Calc Time=0.0044s, SAE Backward Time=0.0457s
# Batch 6/66242: Recon Loss=0.5185, Sparsity Loss=0.0316, Model Forward Time=0.2012s, SAE Forward Time=0.0384s, Loss Calc Time=0.0048s, SAE Backward Time=0.0388s
# Batch 7/66242: Recon Loss=0.5091, Sparsity Loss=0.0336, Model Forward Time=0.2048s, SAE Forward Time=0.0429s, Loss Calc Time=0.0083s, SAE Backward Time=0.0381s
# Batch 8/66242: Recon Loss=0.4946, Sparsity Loss=0.0358, Model Forward Time=0.1964s, SAE Forward Time=0.0418s, Loss Calc Time=0.0077s, SAE Backward Time=0.0362s
# Batch 9/66242: Recon Loss=0.4871, Sparsity Loss=0.0387, Model Forward Time=0.2026s, SAE Forward Time=0.0417s, Loss Calc Time=0.0072s, SAE Backward Time=0.0345s
# Batch 10/66242: Recon Loss=0.4734, Sparsity Loss=0.0408, Model Forward Time=0.1963s, SAE Forward Time=0.0403s, Loss Calc Time=0.0045s, SAE Backward Time=0.0392s
# Batch 11/66242: Recon Loss=0.4664, Sparsity Loss=0.0436, Model Forward Time=0.1978s, SAE Forward Time=0.0388s, Loss Calc Time=0.0039s, SAE Backward Time=0.0443s
# Batch 12/66242: Recon Loss=0.4522, Sparsity Loss=0.0450, Model Forward Time=0.2129s, SAE Forward Time=0.0374s, Loss Calc Time=0.0039s, SAE Backward Time=0.0325s
# Batch 13/66242: Recon Loss=0.4505, Sparsity Loss=0.0470, Model Forward Time=0.2216s, SAE Forward Time=0.0400s, Loss Calc Time=0.0043s, SAE Backward Time=0.0381s
# Batch 14/66242: Recon Loss=0.4332, Sparsity Loss=0.0497, Model Forward Time=0.1989s, SAE Forward Time=0.0358s, Loss Calc Time=0.0044s, SAE Backward Time=0.0332s
# Batch 15/66242: Recon Loss=0.4198, Sparsity Loss=0.0499, Model Forward Time=0.1953s, SAE Forward Time=0.0363s, Loss Calc Time=0.0039s, SAE Backward Time=0.0341s
# Batch 16/66242: Recon Loss=0.4160, Sparsity Loss=0.0506, Model Forward Time=0.2200s, SAE Forward Time=0.0384s, Loss Calc Time=0.0073s, SAE Backward Time=0.0372s
# Batch 17/66242: Recon Loss=0.4047, Sparsity Loss=0.0540, Model Forward Time=0.2057s, SAE Forward Time=0.0392s, Loss Calc Time=0.0059s, SAE Backward Time=0.0363s
# Batch 18/66242: Recon Loss=0.4061, Sparsity Loss=0.0549, Model Forward Time=0.2280s, SAE Forward Time=0.0361s, Loss Calc Time=0.0055s, SAE Backward Time=0.0368s
# Batch 19/66242: Recon Loss=0.3888, Sparsity Loss=0.0565, Model Forward Time=0.1955s, SAE Forward Time=0.0362s, Loss Calc Time=0.0038s, SAE Backward Time=0.0347s
# Batch 20/66242: Recon Loss=0.4025, Sparsity Loss=0.0580, Model Forward Time=0.1939s, SAE Forward Time=0.0378s, Loss Calc Time=0.0038s, SAE Backward Time=0.0322s
# Batch 21/66242: Recon Loss=0.3728, Sparsity Loss=0.0608, Model Forward Time=0.1980s, SAE Forward Time=0.0353s, Loss Calc Time=0.0038s, SAE Backward Time=0.0332s
# Batch 22/66242: Recon Loss=0.3837, Sparsity Loss=0.0603, Model Forward Time=0.1946s, SAE Forward Time=0.0363s, Loss Calc Time=0.0038s, SAE Backward Time=0.0340s
# Batch 23/66242: Recon Loss=0.3651, Sparsity Loss=0.0621, Model Forward Time=0.2029s, SAE Forward Time=0.0351s, Loss Calc Time=0.0038s, SAE Backward Time=0.0325s
# Batch 24/66242: Recon Loss=0.3564, Sparsity Loss=0.0652, Model Forward Time=0.1962s, SAE Forward Time=0.0354s, Loss Calc Time=0.0041s, SAE Backward Time=0.0348s
# Batch 25/66242: Recon Loss=0.3554, Sparsity Loss=0.0662, Model Forward Time=0.1946s, SAE Forward Time=0.0404s, Loss Calc Time=0.0045s, SAE Backward Time=0.0339s
# Batch 26/66242: Recon Loss=0.3494, Sparsity Loss=0.0673, Model Forward Time=0.1957s, SAE Forward Time=0.0353s, Loss Calc Time=0.0038s, SAE Backward Time=0.0344s
# Batch 27/66242: Recon Loss=0.3540, Sparsity Loss=0.0698, Model Forward Time=0.1955s, SAE Forward Time=0.0355s, Loss Calc Time=0.0059s, SAE Backward Time=0.0329s
# Batch 28/66242: Recon Loss=0.3696, Sparsity Loss=0.0704, Model Forward Time=0.1949s, SAE Forward Time=0.0358s, Loss Calc Time=0.0038s, SAE Backward Time=0.0323s
# Batch 29/66242: Recon Loss=0.3384, Sparsity Loss=0.0736, Model Forward Time=0.2047s, SAE Forward Time=0.0375s, Loss Calc Time=0.0042s, SAE Backward Time=0.0328s
# Batch 30/66242: Recon Loss=0.3414, Sparsity Loss=0.0740, Model Forward Time=0.1976s, SAE Forward Time=0.0359s, Loss Calc Time=0.0038s, SAE Backward Time=0.0321s
# Batch 31/66242: Recon Loss=0.3272, Sparsity Loss=0.0761, Model Forward Time=0.1970s, SAE Forward Time=0.0375s, Loss Calc Time=0.0039s, SAE Backward Time=0.0328s
# Batch 32/66242: Recon Loss=0.3167, Sparsity Loss=0.0753, Model Forward Time=0.2005s, SAE Forward Time=0.0352s, Loss Calc Time=0.0038s, SAE Backward Time=0.0342s
# Batch 33/66242: Recon Loss=0.3226, Sparsity Loss=0.0775, Model Forward Time=0.1951s, SAE Forward Time=0.0399s, Loss Calc Time=0.0040s, SAE Backward Time=0.0342s
# Batch 34/66242: Recon Loss=0.3105, Sparsity Loss=0.0772, Model Forward Time=0.1961s, SAE Forward Time=0.0405s, Loss Calc Time=0.0044s, SAE Backward Time=0.0343s
# Batch 35/66242: Recon Loss=0.3096, Sparsity Loss=0.0777, Model Forward Time=0.1964s, SAE Forward Time=0.0405s, Loss Calc Time=0.0039s, SAE Backward Time=0.0344s
# Batch 36/66242: Recon Loss=0.3046, Sparsity Loss=0.0794, Model Forward Time=0.1961s, SAE Forward Time=0.0353s, Loss Calc Time=0.0038s, SAE Backward Time=0.0337s
# Batch 37/66242: Recon Loss=0.2956, Sparsity Loss=0.0821, Model Forward Time=0.1949s, SAE Forward Time=0.0353s, Loss Calc Time=0.0038s, SAE Backward Time=0.0322s
# Batch 38/66242: Recon Loss=0.2925, Sparsity Loss=0.0833, Model Forward Time=1.3707s, SAE Forward Time=0.0355s, Loss Calc Time=0.0040s, SAE Backward Time=0.0338s
# Batch 39/66242: Recon Loss=0.2878, Sparsity Loss=0.0842, Model Forward Time=0.8534s, SAE Forward Time=0.0369s, Loss Calc Time=0.0044s, SAE Backward Time=0.0347s
# Batch 40/66242: Recon Loss=0.2857, Sparsity Loss=0.0858, Model Forward Time=0.2241s, SAE Forward Time=0.0376s, Loss Calc Time=0.0039s, SAE Backward Time=0.0347s
# Batch 41/66242: Recon Loss=0.2914, Sparsity Loss=0.0853, Model Forward Time=0.1938s, SAE Forward Time=0.0392s, Loss Calc Time=0.0053s, SAE Backward Time=0.0372s
# Batch 42/66242: Recon Loss=0.2834, Sparsity Loss=0.0898, Model Forward Time=0.1953s, SAE Forward Time=0.0414s, Loss Calc Time=0.0044s, SAE Backward Time=0.0406s
# Batch 43/66242: Recon Loss=0.2785, Sparsity Loss=0.0896, Model Forward Time=0.1950s, SAE Forward Time=0.0454s, Loss Calc Time=0.0064s, SAE Backward Time=0.0376s
# Batch 44/66242: Recon Loss=0.2742, Sparsity Loss=0.0907, Model Forward Time=0.1988s, SAE Forward Time=0.0363s, Loss Calc Time=0.0037s, SAE Backward Time=0.0366s
# Batch 45/66242: Recon Loss=0.2681, Sparsity Loss=0.0914, Model Forward Time=0.1972s, SAE Forward Time=0.0367s, Loss Calc Time=0.0037s, SAE Backward Time=0.0333s
# Batch 46/66242: Recon Loss=0.2783, Sparsity Loss=0.0922, Model Forward Time=0.2592s, SAE Forward Time=0.0367s, Loss Calc Time=0.0041s, SAE Backward Time=0.0444s
# Batch 47/66242: Recon Loss=0.3129, Sparsity Loss=0.0923, Model Forward Time=0.1949s, SAE Forward Time=0.0448s, Loss Calc Time=0.0046s, SAE Backward Time=0.0329s
# Batch 48/66242: Recon Loss=0.2644, Sparsity Loss=0.0926, Model Forward Time=0.2000s, SAE Forward Time=0.0358s, Loss Calc Time=0.0039s, SAE Backward Time=0.0331s
# Batch 49/66242: Recon Loss=0.2590, Sparsity Loss=0.0920, Model Forward Time=0.1991s, SAE Forward Time=0.0383s, Loss Calc Time=0.0038s, SAE Backward Time=0.0324s
# Batch 50/66242: Recon Loss=0.2658, Sparsity Loss=0.0907, Model Forward Time=0.1957s, SAE Forward Time=0.0358s, Loss Calc Time=0.0043s, SAE Backward Time=0.0343s
# Batch 51/66242: Recon Loss=0.2637, Sparsity Loss=0.0911, Model Forward Time=0.2000s, SAE Forward Time=0.0354s, Loss Calc Time=0.0037s, SAE Backward Time=0.0332s
# Batch 52/66242: Recon Loss=0.2647, Sparsity Loss=0.0925, Model Forward Time=0.1985s, SAE Forward Time=0.0381s, Loss Calc Time=0.0038s, SAE Backward Time=0.0343s
# Batch 53/66242: Recon Loss=0.2670, Sparsity Loss=0.0930, Model Forward Time=0.3151s, SAE Forward Time=0.0371s, Loss Calc Time=0.0044s, SAE Backward Time=0.0348s
# Batch 54/66242: Recon Loss=0.2440, Sparsity Loss=0.0949, Model Forward Time=0.9960s, SAE Forward Time=0.0395s, Loss Calc Time=0.0047s, SAE Backward Time=0.0333s
# Batch 55/66242: Recon Loss=0.2638, Sparsity Loss=0.0943, Model Forward Time=0.5149s, SAE Forward Time=0.0356s, Loss Calc Time=0.0039s, SAE Backward Time=0.0352s
# Batch 56/66242: Recon Loss=0.2540, Sparsity Loss=0.0959, Model Forward Time=0.2368s, SAE Forward Time=0.0355s, Loss Calc Time=0.0040s, SAE Backward Time=0.0335s
# Batch 57/66242: Recon Loss=0.2496, Sparsity Loss=0.0947, Model Forward Time=0.2067s, SAE Forward Time=0.0367s, Loss Calc Time=0.0041s, SAE Backward Time=0.0348s
# Batch 58/66242: Recon Loss=0.2478, Sparsity Loss=0.0950, Model Forward Time=0.1974s, SAE Forward Time=0.0399s, Loss Calc Time=0.0045s, SAE Backward Time=0.0337s
# Batch 59/66242: Recon Loss=0.2348, Sparsity Loss=0.0967, Model Forward Time=0.1964s, SAE Forward Time=0.0369s, Loss Calc Time=0.0047s, SAE Backward Time=0.0326s
# Batch 60/66242: Recon Loss=0.2527, Sparsity Loss=0.0963, Model Forward Time=0.2005s, SAE Forward Time=0.0356s, Loss Calc Time=0.0046s, SAE Backward Time=0.0361s
# Batch 61/66242: Recon Loss=0.2418, Sparsity Loss=0.0964, Model Forward Time=0.4354s, SAE Forward Time=0.0481s, Loss Calc Time=0.0074s, SAE Backward Time=0.0432s
# Batch 62/66242: Recon Loss=0.2476, Sparsity Loss=0.0961, Model Forward Time=0.9598s, SAE Forward Time=0.0394s, Loss Calc Time=0.0053s, SAE Backward Time=0.0373s
# Batch 63/66242: Recon Loss=0.2399, Sparsity Loss=0.0979, Model Forward Time=0.6208s, SAE Forward Time=0.0353s, Loss Calc Time=0.0038s, SAE Backward Time=0.0336s
# Batch 64/66242: Recon Loss=0.2296, Sparsity Loss=0.0981, Model Forward Time=0.2235s, SAE Forward Time=0.0353s, Loss Calc Time=0.0041s, SAE Backward Time=0.0326s
# Batch 65/66242: Recon Loss=0.2323, Sparsity Loss=0.0981, Model Forward Time=0.1932s, SAE Forward Time=0.0370s, Loss Calc Time=0.0038s, SAE Backward Time=0.0331s
# Batch 66/66242: Recon Loss=0.2212, Sparsity Loss=0.0983, Model Forward Time=0.1984s, SAE Forward Time=0.0370s, Loss Calc Time=0.0045s, SAE Backward Time=0.0320s
# Batch 67/66242: Recon Loss=0.2415, Sparsity Loss=0.0957, Model Forward Time=0.4301s, SAE Forward Time=0.0396s, Loss Calc Time=0.0041s, SAE Backward Time=0.0342s
# Batch 68/66242: Recon Loss=0.2286, Sparsity Loss=0.0974, Model Forward Time=0.2220s, SAE Forward Time=0.0353s, Loss Calc Time=0.0038s, SAE Backward Time=0.0340s
# Batch 69/66242: Recon Loss=0.2170, Sparsity Loss=0.0960, Model Forward Time=0.2021s, SAE Forward Time=0.0362s, Loss Calc Time=0.0038s, SAE Backward Time=0.0321s
# Batch 70/66242: Recon Loss=0.2266, Sparsity Loss=0.0957, Model Forward Time=0.1951s, SAE Forward Time=0.0383s, Loss Calc Time=0.0039s, SAE Backward Time=0.0329s
# Batch 71/66242: Recon Loss=0.2328, Sparsity Loss=0.0948, Model Forward Time=0.1978s, SAE Forward Time=0.0351s, Loss Calc Time=0.0038s, SAE Backward Time=0.0344s
# Batch 72/66242: Recon Loss=0.2195, Sparsity Loss=0.0975, Model Forward Time=0.1959s, SAE Forward Time=0.0362s, Loss Calc Time=0.0037s, SAE Backward Time=0.0322s
# Batch 73/66242: Recon Loss=0.2287, Sparsity Loss=0.0972, Model Forward Time=0.2001s, SAE Forward Time=0.0371s, Loss Calc Time=0.0040s, SAE Backward Time=0.0334s
# Batch 74/66242: Recon Loss=0.2293, Sparsity Loss=0.0971, Model Forward Time=0.1947s, SAE Forward Time=0.0361s, Loss Calc Time=0.0038s, SAE Backward Time=0.0335s
# Batch 75/66242: Recon Loss=0.2388, Sparsity Loss=0.0977, Model Forward Time=0.1987s, SAE Forward Time=0.0374s, Loss Calc Time=0.0037s, SAE Backward Time=0.0331s
# Batch 76/66242: Recon Loss=0.2467, Sparsity Loss=0.0991, Model Forward Time=0.1955s, SAE Forward Time=0.0352s, Loss Calc Time=0.0038s, SAE Backward Time=0.0345s
# Batch 77/66242: Recon Loss=0.2090, Sparsity Loss=0.0972, Model Forward Time=0.1945s, SAE Forward Time=0.0368s, Loss Calc Time=0.0037s, SAE Backward Time=0.0339s
# Batch 78/66242: Recon Loss=0.2136, Sparsity Loss=0.0975, Model Forward Time=0.1974s, SAE Forward Time=0.0353s, Loss Calc Time=0.0053s, SAE Backward Time=0.0333s
# Batch 79/66242: Recon Loss=0.2114, Sparsity Loss=0.0960, Model Forward Time=0.2022s, SAE Forward Time=0.0410s, Loss Calc Time=0.0076s, SAE Backward Time=0.0373s
# Batch 80/66242: Recon Loss=0.2129, Sparsity Loss=0.0968, Model Forward Time=0.1972s, SAE Forward Time=0.0372s, Loss Calc Time=0.0039s, SAE Backward Time=0.0322s
# Batch 81/66242: Recon Loss=0.2206, Sparsity Loss=0.0962, Model Forward Time=0.1954s, SAE Forward Time=0.0362s, Loss Calc Time=0.0039s, SAE Backward Time=0.0359s
# Batch 82/66242: Recon Loss=0.2099, Sparsity Loss=0.0973, Model Forward Time=0.1959s, SAE Forward Time=0.0402s, Loss Calc Time=0.0225s, SAE Backward Time=0.0168s
# Batch 83/66242: Recon Loss=0.1984, Sparsity Loss=0.0969, Model Forward Time=0.2002s, SAE Forward Time=0.0352s, Loss Calc Time=0.0038s, SAE Backward Time=0.0330s
# Batch 84/66242: Recon Loss=0.2099, Sparsity Loss=0.0971, Model Forward Time=0.1946s, SAE Forward Time=0.0369s, Loss Calc Time=0.0044s, SAE Backward Time=0.0322s
# Batch 85/66242: Recon Loss=0.2228, Sparsity Loss=0.0965, Model Forward Time=0.2412s, SAE Forward Time=0.0476s, Loss Calc Time=0.0041s, SAE Backward Time=0.0326s
# Batch 86/66242: Recon Loss=0.1962, Sparsity Loss=0.0969, Model Forward Time=0.1994s, SAE Forward Time=0.0358s, Loss Calc Time=0.0057s, SAE Backward Time=0.0330s
# Batch 87/66242: Recon Loss=0.2139, Sparsity Loss=0.0967, Model Forward Time=0.1958s, SAE Forward Time=0.0360s, Loss Calc Time=0.0037s, SAE Backward Time=0.0331s
# Batch 88/66242: Recon Loss=0.2101, Sparsity Loss=0.0966, Model Forward Time=0.2158s, SAE Forward Time=0.0353s, Loss Calc Time=0.0038s, SAE Backward Time=0.0340s
# Batch 89/66242: Recon Loss=0.2093, Sparsity Loss=0.0968, Model Forward Time=0.2195s, SAE Forward Time=0.0369s, Loss Calc Time=0.0038s, SAE Backward Time=0.0344s
# Batch 90/66242: Recon Loss=0.2171, Sparsity Loss=0.0964, Model Forward Time=0.1963s, SAE Forward Time=0.0369s, Loss Calc Time=0.0038s, SAE Backward Time=0.0325s
# Batch 91/66242: Recon Loss=0.2006, Sparsity Loss=0.0964, Model Forward Time=0.1942s, SAE Forward Time=0.0361s, Loss Calc Time=0.0041s, SAE Backward Time=0.0339s
# Batch 92/66242: Recon Loss=0.1946, Sparsity Loss=0.0957, Model Forward Time=0.1983s, SAE Forward Time=0.0370s, Loss Calc Time=0.0043s, SAE Backward Time=0.0339s
# Batch 93/66242: Recon Loss=0.2043, Sparsity Loss=0.0947, Model Forward Time=0.1958s, SAE Forward Time=0.0379s, Loss Calc Time=0.0040s, SAE Backward Time=0.0333s
# Batch 94/66242: Recon Loss=0.2115, Sparsity Loss=0.0965, Model Forward Time=0.2536s, SAE Forward Time=0.0463s, Loss Calc Time=0.0047s, SAE Backward Time=0.0334s
# Batch 95/66242: Recon Loss=0.1923, Sparsity Loss=0.0969, Model Forward Time=0.2003s, SAE Forward Time=0.0383s, Loss Calc Time=0.0031s, SAE Backward Time=0.0342s
# Batch 96/66242: Recon Loss=0.2015, Sparsity Loss=0.0969, Model Forward Time=0.1969s, SAE Forward Time=0.0359s, Loss Calc Time=0.0038s, SAE Backward Time=0.0334s
# Batch 97/66242: Recon Loss=0.2099, Sparsity Loss=0.0971, Model Forward Time=0.1944s, SAE Forward Time=0.0373s, Loss Calc Time=0.0039s, SAE Backward Time=0.0332s
# Batch 98/66242: Recon Loss=0.1875, Sparsity Loss=0.0963, Model Forward Time=0.1986s, SAE Forward Time=0.0362s, Loss Calc Time=0.0037s, SAE Backward Time=0.0359s
# Batch 99/66242: Recon Loss=0.1910, Sparsity Loss=0.0956, Model Forward Time=0.1985s, SAE Forward Time=0.0505s, Loss Calc Time=0.0072s, SAE Backward Time=0.0449s
# Batch 100/66242: Recon Loss=0.2035, Sparsity Loss=0.0960, Model Forward Time=0.2145s, SAE Forward Time=0.0399s, Loss Calc Time=0.0051s, SAE Backward Time=0.0327s
# Batch 101/66242: Recon Loss=0.2023, Sparsity Loss=0.0975, Model Forward Time=0.1967s, SAE Forward Time=0.0379s, Loss Calc Time=0.0041s, SAE Backward Time=0.0361s
# Batch 102/66242: Recon Loss=0.1898, Sparsity Loss=0.0950, Model Forward Time=0.2085s, SAE Forward Time=0.0353s, Loss Calc Time=0.0038s, SAE Backward Time=0.0332s
# Batch 103/66242: Recon Loss=0.2103, Sparsity Loss=0.0977, Model Forward Time=0.1983s, SAE Forward Time=0.0373s, Loss Calc Time=0.0044s, SAE Backward Time=0.0320s
# Batch 104/66242: Recon Loss=0.1860, Sparsity Loss=0.0958, Model Forward Time=0.1972s, SAE Forward Time=0.0352s, Loss Calc Time=0.0038s, SAE Backward Time=0.0351s
# Batch 105/66242: Recon Loss=0.1873, Sparsity Loss=0.0948, Model Forward Time=0.6391s, SAE Forward Time=0.0474s, Loss Calc Time=0.0081s, SAE Backward Time=0.0394s
# Batch 106/66242: Recon Loss=0.2165, Sparsity Loss=0.0957, Model Forward Time=0.4911s, SAE Forward Time=0.0357s, Loss Calc Time=0.0038s, SAE Backward Time=0.0346s
# Batch 107/66242: Recon Loss=0.1910, Sparsity Loss=0.0947, Model Forward Time=0.2187s, SAE Forward Time=0.0375s, Loss Calc Time=0.0038s, SAE Backward Time=0.0335s
# Batch 108/66242: Recon Loss=0.1871, Sparsity Loss=0.0948, Model Forward Time=0.2003s, SAE Forward Time=0.0375s, Loss Calc Time=0.0041s, SAE Backward Time=0.0347s
# Batch 109/66242: Recon Loss=0.1918, Sparsity Loss=0.0969, Model Forward Time=0.1990s, SAE Forward Time=0.0365s, Loss Calc Time=0.0037s, SAE Backward Time=0.0338s
# Batch 110/66242: Recon Loss=0.1795, Sparsity Loss=0.0951, Model Forward Time=0.1959s, SAE Forward Time=0.0379s, Loss Calc Time=0.0037s, SAE Backward Time=0.0325s
# Batch 111/66242: Recon Loss=0.1825, Sparsity Loss=0.0947, Model Forward Time=0.1974s, SAE Forward Time=0.0366s, Loss Calc Time=0.0038s, SAE Backward Time=0.0345s
# Batch 112/66242: Recon Loss=0.1802, Sparsity Loss=0.0953, Model Forward Time=0.1957s, SAE Forward Time=0.0359s, Loss Calc Time=0.0037s, SAE Backward Time=0.0324s
# Batch 113/66242: Recon Loss=0.1766, Sparsity Loss=0.0978, Model Forward Time=0.1970s, SAE Forward Time=0.0383s, Loss Calc Time=0.0036s, SAE Backward Time=0.0321s
# Batch 114/66242: Recon Loss=0.1756, Sparsity Loss=0.0967, Model Forward Time=0.1974s, SAE Forward Time=0.0416s, Loss Calc Time=0.0042s, SAE Backward Time=0.0356s
# Batch 115/66242: Recon Loss=0.1746, Sparsity Loss=0.0948, Model Forward Time=0.1958s, SAE Forward Time=0.0445s, Loss Calc Time=0.0037s, SAE Backward Time=0.0323s
# Batch 116/66242: Recon Loss=0.1931, Sparsity Loss=0.0959, Model Forward Time=0.1985s, SAE Forward Time=0.0425s, Loss Calc Time=0.0039s, SAE Backward Time=0.0343s
# Batch 117/66242: Recon Loss=0.1687, Sparsity Loss=0.0965, Model Forward Time=0.1959s, SAE Forward Time=0.0415s, Loss Calc Time=0.0038s, SAE Backward Time=0.0326s
# Batch 118/66242: Recon Loss=0.1936, Sparsity Loss=0.0956, Model Forward Time=0.1942s, SAE Forward Time=0.0451s, Loss Calc Time=0.0039s, SAE Backward Time=0.0346s
# Batch 119/66242: Recon Loss=0.1803, Sparsity Loss=0.0986, Model Forward Time=0.1959s, SAE Forward Time=0.0422s, Loss Calc Time=0.0036s, SAE Backward Time=0.0350s
# Batch 120/66242: Recon Loss=0.1894, Sparsity Loss=0.0975, Model Forward Time=0.1941s, SAE Forward Time=0.0433s, Loss Calc Time=0.0037s, SAE Backward Time=0.0320s
# Batch 121/66242: Recon Loss=0.1805, Sparsity Loss=0.0971, Model Forward Time=0.2014s, SAE Forward Time=0.0369s, Loss Calc Time=0.0060s, SAE Backward Time=0.0350s
# Batch 122/66242: Recon Loss=0.1906, Sparsity Loss=0.0957, Model Forward Time=0.1961s, SAE Forward Time=0.0359s, Loss Calc Time=0.0042s, SAE Backward Time=0.0335s
# Batch 123/66242: Recon Loss=0.1726, Sparsity Loss=0.0962, Model Forward Time=0.2252s, SAE Forward Time=0.0383s, Loss Calc Time=0.0036s, SAE Backward Time=0.0366s
# Batch 124/66242: Recon Loss=0.1809, Sparsity Loss=0.0967, Model Forward Time=0.2414s, SAE Forward Time=0.0355s, Loss Calc Time=0.0038s, SAE Backward Time=0.0351s
# Batch 125/66242: Recon Loss=0.1930, Sparsity Loss=0.0936, Model Forward Time=0.1992s, SAE Forward Time=0.0353s, Loss Calc Time=0.0038s, SAE Backward Time=0.0325s
# Batch 126/66242: Recon Loss=0.1706, Sparsity Loss=0.0944, Model Forward Time=0.1950s, SAE Forward Time=0.0377s, Loss Calc Time=0.0042s, SAE Backward Time=0.0323s
# Batch 127/66242: Recon Loss=0.1723, Sparsity Loss=0.0975, Model Forward Time=0.2020s, SAE Forward Time=0.0365s, Loss Calc Time=0.0043s, SAE Backward Time=0.0338s
# Batch 128/66242: Recon Loss=0.1790, Sparsity Loss=0.0949, Model Forward Time=0.2149s, SAE Forward Time=0.0413s, Loss Calc Time=0.0052s, SAE Backward Time=0.0369s
# Batch 129/66242: Recon Loss=0.1752, Sparsity Loss=0.0978, Model Forward Time=0.2016s, SAE Forward Time=0.0365s, Loss Calc Time=0.0076s, SAE Backward Time=0.0335s
# Batch 130/66242: Recon Loss=0.1818, Sparsity Loss=0.0950, Model Forward Time=0.1991s, SAE Forward Time=0.0416s, Loss Calc Time=0.0066s, SAE Backward Time=0.0378s
# Batch 131/66242: Recon Loss=0.1743, Sparsity Loss=0.0970, Model Forward Time=0.2044s, SAE Forward Time=0.0381s, Loss Calc Time=0.0045s, SAE Backward Time=0.0323s
# Batch 132/66242: Recon Loss=0.1801, Sparsity Loss=0.0942, Model Forward Time=0.2023s, SAE Forward Time=0.0391s, Loss Calc Time=0.0044s, SAE Backward Time=0.0334s
# Batch 133/66242: Recon Loss=0.1853, Sparsity Loss=0.0954, Model Forward Time=0.2035s, SAE Forward Time=0.0380s, Loss Calc Time=0.0043s, SAE Backward Time=0.0364s
# Batch 134/66242: Recon Loss=0.1799, Sparsity Loss=0.0936, Model Forward Time=0.3042s, SAE Forward Time=0.0368s, Loss Calc Time=0.0042s, SAE Backward Time=0.0331s
# Batch 135/66242: Recon Loss=0.1907, Sparsity Loss=0.0953, Model Forward Time=0.7513s, SAE Forward Time=0.0447s, Loss Calc Time=0.0057s, SAE Backward Time=0.0369s
# Batch 136/66242: Recon Loss=0.1761, Sparsity Loss=0.0953, Model Forward Time=1.4513s, SAE Forward Time=0.0367s, Loss Calc Time=0.0051s, SAE Backward Time=0.0370s
# Batch 137/66242: Recon Loss=0.1770, Sparsity Loss=0.0936, Model Forward Time=1.7489s, SAE Forward Time=0.0058s, Loss Calc Time=0.0018s, SAE Backward Time=0.0030s
# Batch 138/66242: Recon Loss=0.1675, Sparsity Loss=0.0965, Model Forward Time=1.8411s, SAE Forward Time=0.0364s, Loss Calc Time=0.0047s, SAE Backward Time=0.0345s
# Batch 139/66242: Recon Loss=0.1695, Sparsity Loss=0.0919, Model Forward Time=0.2327s, SAE Forward Time=0.0473s, Loss Calc Time=0.0051s, SAE Backward Time=0.0342s
# Batch 140/66242: Recon Loss=0.1596, Sparsity Loss=0.0934, Model Forward Time=0.2360s, SAE Forward Time=0.0388s, Loss Calc Time=0.0044s, SAE Backward Time=0.0341s
# Batch 141/66242: Recon Loss=0.1674, Sparsity Loss=0.0936, Model Forward Time=0.2016s, SAE Forward Time=0.0385s, Loss Calc Time=0.0039s, SAE Backward Time=0.0327s
# Batch 142/66242: Recon Loss=0.1754, Sparsity Loss=0.0950, Model Forward Time=0.1948s, SAE Forward Time=0.0362s, Loss Calc Time=0.0036s, SAE Backward Time=0.0322s
# Batch 143/66242: Recon Loss=0.1751, Sparsity Loss=0.0933, Model Forward Time=0.1954s, SAE Forward Time=0.0405s, Loss Calc Time=0.0068s, SAE Backward Time=0.0335s
# Batch 144/66242: Recon Loss=0.1709, Sparsity Loss=0.0942, Model Forward Time=0.1962s, SAE Forward Time=0.0411s, Loss Calc Time=0.0037s, SAE Backward Time=0.0339s
# Batch 145/66242: Recon Loss=0.1687, Sparsity Loss=0.0944, Model Forward Time=0.1964s, SAE Forward Time=0.0398s, Loss Calc Time=0.0070s, SAE Backward Time=0.0319s
# Batch 146/66242: Recon Loss=0.1583, Sparsity Loss=0.0930, Model Forward Time=0.2003s, SAE Forward Time=0.0415s, Loss Calc Time=0.0037s, SAE Backward Time=0.0345s
# Batch 147/66242: Recon Loss=0.1754, Sparsity Loss=0.0946, Model Forward Time=0.1965s, SAE Forward Time=0.0444s, Loss Calc Time=0.0040s, SAE Backward Time=0.0336s
# Batch 148/66242: Recon Loss=0.1664, Sparsity Loss=0.0961, Model Forward Time=0.2029s, SAE Forward Time=0.0415s, Loss Calc Time=0.0038s, SAE Backward Time=0.0355s
# Batch 149/66242: Recon Loss=0.1711, Sparsity Loss=0.0953, Model Forward Time=0.1968s, SAE Forward Time=0.0420s, Loss Calc Time=0.0044s, SAE Backward Time=0.0322s
# Batch 150/66242: Recon Loss=0.1673, Sparsity Loss=0.0928, Model Forward Time=0.2020s, SAE Forward Time=0.0355s, Loss Calc Time=0.0044s, SAE Backward Time=0.0364s
# Batch 151/66242: Recon Loss=0.1596, Sparsity Loss=0.0931, Model Forward Time=0.2257s, SAE Forward Time=0.0306s, Loss Calc Time=0.0060s, SAE Backward Time=0.0381s
# Batch 152/66242: Recon Loss=0.1702, Sparsity Loss=0.0965, Model Forward Time=0.2318s, SAE Forward Time=0.0452s, Loss Calc Time=0.0042s, SAE Backward Time=0.0378s
# Batch 153/66242: Recon Loss=0.1629, Sparsity Loss=0.0941, Model Forward Time=0.2016s, SAE Forward Time=0.0371s, Loss Calc Time=0.0038s, SAE Backward Time=0.0321s
# Batch 154/66242: Recon Loss=0.1675, Sparsity Loss=0.0943, Model Forward Time=0.2054s, SAE Forward Time=0.0372s, Loss Calc Time=0.0047s, SAE Backward Time=0.0330s
# Batch 155/66242: Recon Loss=0.1561, Sparsity Loss=0.0938, Model Forward Time=0.1970s, SAE Forward Time=0.0354s, Loss Calc Time=0.0042s, SAE Backward Time=0.0354s
# Batch 156/66242: Recon Loss=0.1738, Sparsity Loss=0.0922, Model Forward Time=0.2020s, SAE Forward Time=0.0362s, Loss Calc Time=0.0038s, SAE Backward Time=0.0323s
# Batch 157/66242: Recon Loss=0.1587, Sparsity Loss=0.0940, Model Forward Time=0.1954s, SAE Forward Time=0.0360s, Loss Calc Time=0.0037s, SAE Backward Time=0.0346s
# Batch 158/66242: Recon Loss=0.1645, Sparsity Loss=0.0934, Model Forward Time=0.1954s, SAE Forward Time=0.0410s, Loss Calc Time=0.0070s, SAE Backward Time=0.0346s
# Batch 159/66242: Recon Loss=0.1562, Sparsity Loss=0.0947, Model Forward Time=0.2129s, SAE Forward Time=0.0433s, Loss Calc Time=0.0055s, SAE Backward Time=0.0383s
# Batch 160/66242: Recon Loss=0.1538, Sparsity Loss=0.0946, Model Forward Time=0.2146s, SAE Forward Time=0.0434s, Loss Calc Time=0.0053s, SAE Backward Time=0.0361s
# Batch 161/66242: Recon Loss=0.1595, Sparsity Loss=0.0924, Model Forward Time=0.1998s, SAE Forward Time=0.0368s, Loss Calc Time=0.0046s, SAE Backward Time=0.0350s
# Batch 162/66242: Recon Loss=0.1552, Sparsity Loss=0.0925, Model Forward Time=0.2097s, SAE Forward Time=0.0401s, Loss Calc Time=0.0050s, SAE Backward Time=0.0397s
# Batch 163/66242: Recon Loss=0.1573, Sparsity Loss=0.0932, Model Forward Time=0.2085s, SAE Forward Time=0.0384s, Loss Calc Time=0.0042s, SAE Backward Time=0.0381s
# Batch 164/66242: Recon Loss=0.1508, Sparsity Loss=0.0920, Model Forward Time=1.8171s, SAE Forward Time=0.0401s, Loss Calc Time=0.0060s, SAE Backward Time=0.0402s
# Batch 165/66242: Recon Loss=0.1596, Sparsity Loss=0.0906, Model Forward Time=0.5626s, SAE Forward Time=0.0406s, Loss Calc Time=0.0047s, SAE Backward Time=0.0352s
# Batch 166/66242: Recon Loss=0.1619, Sparsity Loss=0.0934, Model Forward Time=0.2395s, SAE Forward Time=0.0375s, Loss Calc Time=0.0040s, SAE Backward Time=0.0346s
# Batch 167/66242: Recon Loss=0.1462, Sparsity Loss=0.0938, Model Forward Time=0.6289s, SAE Forward Time=0.0404s, Loss Calc Time=0.0064s, SAE Backward Time=0.0356s
# Batch 168/66242: Recon Loss=0.1534, Sparsity Loss=0.0951, Model Forward Time=0.2412s, SAE Forward Time=0.0369s, Loss Calc Time=0.0066s, SAE Backward Time=0.0359s
# Batch 169/66242: Recon Loss=0.1561, Sparsity Loss=0.0953, Model Forward Time=0.2076s, SAE Forward Time=0.0398s, Loss Calc Time=0.0053s, SAE Backward Time=0.0340s
# Batch 170/66242: Recon Loss=0.1499, Sparsity Loss=0.0942, Model Forward Time=1.6652s, SAE Forward Time=0.0396s, Loss Calc Time=0.0045s, SAE Backward Time=0.0366s
# Batch 171/66242: Recon Loss=0.1533, Sparsity Loss=0.0931, Model Forward Time=0.7851s, SAE Forward Time=0.0388s, Loss Calc Time=0.0049s, SAE Backward Time=0.0355s
# Batch 172/66242: Recon Loss=0.1473, Sparsity Loss=0.0937, Model Forward Time=0.2324s, SAE Forward Time=0.0373s, Loss Calc Time=0.0043s, SAE Backward Time=0.0399s
# Batch 173/66242: Recon Loss=0.1475, Sparsity Loss=0.0940, Model Forward Time=0.2026s, SAE Forward Time=0.0363s, Loss Calc Time=0.0038s, SAE Backward Time=0.0371s
# Batch 174/66242: Recon Loss=0.1516, Sparsity Loss=0.0935, Model Forward Time=0.2014s, SAE Forward Time=0.0369s, Loss Calc Time=0.0041s, SAE Backward Time=0.0339s
# Batch 175/66242: Recon Loss=0.1638, Sparsity Loss=0.0952, Model Forward Time=0.2040s, SAE Forward Time=0.0379s, Loss Calc Time=0.0038s, SAE Backward Time=0.0359s
# Batch 176/66242: Recon Loss=0.1490, Sparsity Loss=0.0925, Model Forward Time=0.2065s, SAE Forward Time=0.0403s, Loss Calc Time=0.0057s, SAE Backward Time=0.0344s
# Batch 177/66242: Recon Loss=0.1477, Sparsity Loss=0.0932, Model Forward Time=0.2264s, SAE Forward Time=0.0411s, Loss Calc Time=0.0039s, SAE Backward Time=0.0377s
# Batch 178/66242: Recon Loss=0.1639, Sparsity Loss=0.0944, Model Forward Time=0.2530s, SAE Forward Time=0.2198s, Loss Calc Time=0.0165s, SAE Backward Time=0.0067s
# Batch 179/66242: Recon Loss=0.1664, Sparsity Loss=0.0930, Model Forward Time=0.5176s, SAE Forward Time=0.0369s, Loss Calc Time=0.0052s, SAE Backward Time=0.0357s
# Batch 180/66242: Recon Loss=0.1536, Sparsity Loss=0.0938, Model Forward Time=0.2356s, SAE Forward Time=0.0387s, Loss Calc Time=0.0056s, SAE Backward Time=0.0343s
# Batch 181/66242: Recon Loss=0.1558, Sparsity Loss=0.0928, Model Forward Time=0.2072s, SAE Forward Time=0.0405s, Loss Calc Time=0.0040s, SAE Backward Time=0.0335s
# Batch 182/66242: Recon Loss=0.1556, Sparsity Loss=0.0920, Model Forward Time=0.2051s, SAE Forward Time=0.0382s, Loss Calc Time=0.0037s, SAE Backward Time=0.0353s
# Batch 183/66242: Recon Loss=0.1440, Sparsity Loss=0.0919, Model Forward Time=0.2110s, SAE Forward Time=0.0386s, Loss Calc Time=0.0057s, SAE Backward Time=0.0352s
# Batch 184/66242: Recon Loss=0.1548, Sparsity Loss=0.0929, Model Forward Time=0.1997s, SAE Forward Time=0.0390s, Loss Calc Time=0.0042s, SAE Backward Time=0.0337s
# Batch 185/66242: Recon Loss=0.1433, Sparsity Loss=0.0931, Model Forward Time=0.2044s, SAE Forward Time=0.0376s, Loss Calc Time=0.0059s, SAE Backward Time=0.0325s
# Batch 186/66242: Recon Loss=0.1555, Sparsity Loss=0.0902, Model Forward Time=0.2004s, SAE Forward Time=0.0382s, Loss Calc Time=0.0043s, SAE Backward Time=0.0337s
# Batch 187/66242: Recon Loss=0.1523, Sparsity Loss=0.0916, Model Forward Time=0.2148s, SAE Forward Time=0.0457s, Loss Calc Time=0.0007s, SAE Backward Time=0.0320s
# Batch 188/66242: Recon Loss=0.1534, Sparsity Loss=0.0924, Model Forward Time=0.2028s, SAE Forward Time=0.0402s, Loss Calc Time=0.0048s, SAE Backward Time=0.0346s
# Batch 189/66242: Recon Loss=0.1477, Sparsity Loss=0.0927, Model Forward Time=0.2075s, SAE Forward Time=0.0389s, Loss Calc Time=0.0053s, SAE Backward Time=0.0336s
# Batch 190/66242: Recon Loss=0.1525, Sparsity Loss=0.0933, Model Forward Time=0.2014s, SAE Forward Time=0.0363s, Loss Calc Time=0.0039s, SAE Backward Time=0.0337s
# Batch 191/66242: Recon Loss=0.1608, Sparsity Loss=0.0931, Model Forward Time=0.2030s, SAE Forward Time=0.0371s, Loss Calc Time=0.0038s, SAE Backward Time=0.0336s
# Batch 192/66242: Recon Loss=0.1426, Sparsity Loss=0.0883, Model Forward Time=0.3151s, SAE Forward Time=0.0378s, Loss Calc Time=0.0040s, SAE Backward Time=0.0362s
# Batch 193/66242: Recon Loss=0.1474, Sparsity Loss=0.0901, Model Forward Time=0.4888s, SAE Forward Time=0.0388s, Loss Calc Time=0.0046s, SAE Backward Time=0.0356s
# Batch 194/66242: Recon Loss=0.1442, Sparsity Loss=0.0901, Model Forward Time=0.6654s, SAE Forward Time=0.0429s, Loss Calc Time=0.0044s, SAE Backward Time=0.0353s
# Batch 195/66242: Recon Loss=0.1510, Sparsity Loss=0.0926, Model Forward Time=0.9244s, SAE Forward Time=0.0365s, Loss Calc Time=0.0041s, SAE Backward Time=0.0354s
# Batch 196/66242: Recon Loss=0.1497, Sparsity Loss=0.0911, Model Forward Time=0.2493s, SAE Forward Time=0.0430s, Loss Calc Time=0.0044s, SAE Backward Time=0.0365s
# Batch 197/66242: Recon Loss=0.1515, Sparsity Loss=0.0902, Model Forward Time=0.2382s, SAE Forward Time=0.0400s, Loss Calc Time=0.0045s, SAE Backward Time=0.0380s
# Batch 198/66242: Recon Loss=0.1460, Sparsity Loss=0.0911, Model Forward Time=0.2045s, SAE Forward Time=0.0386s, Loss Calc Time=0.0037s, SAE Backward Time=0.0348s
# Batch 199/66242: Recon Loss=0.1565, Sparsity Loss=0.0914, Model Forward Time=0.2008s, SAE Forward Time=0.0394s, Loss Calc Time=0.0058s, SAE Backward Time=0.0369s
# Batch 200/66242: Recon Loss=0.1489, Sparsity Loss=0.0921, Model Forward Time=0.2012s, SAE Forward Time=0.0378s, Loss Calc Time=0.0039s, SAE Backward Time=0.0341s
# Batch 201/66242: Recon Loss=0.1397, Sparsity Loss=0.0898, Model Forward Time=0.2005s, SAE Forward Time=0.0388s, Loss Calc Time=0.0042s, SAE Backward Time=0.0349s
# Batch 202/66242: Recon Loss=0.1462, Sparsity Loss=0.0896, Model Forward Time=0.2121s, SAE Forward Time=0.0364s, Loss Calc Time=0.0038s, SAE Backward Time=0.0371s
# Batch 203/66242: Recon Loss=0.1461, Sparsity Loss=0.0912, Model Forward Time=0.2090s, SAE Forward Time=0.0381s, Loss Calc Time=0.0053s, SAE Backward Time=0.0360s
# Batch 204/66242: Recon Loss=0.1545, Sparsity Loss=0.0889, Model Forward Time=0.2032s, SAE Forward Time=0.0385s, Loss Calc Time=0.0045s, SAE Backward Time=0.0372s
# Batch 205/66242: Recon Loss=0.1505, Sparsity Loss=0.0943, Model Forward Time=0.3150s, SAE Forward Time=0.0402s, Loss Calc Time=0.0040s, SAE Backward Time=0.0381s
# Batch 206/66242: Recon Loss=0.1526, Sparsity Loss=0.0919, Model Forward Time=0.2468s, SAE Forward Time=0.0405s, Loss Calc Time=0.0046s, SAE Backward Time=0.0358s
# Batch 207/66242: Recon Loss=0.1448, Sparsity Loss=0.0907, Model Forward Time=0.2002s, SAE Forward Time=0.0400s, Loss Calc Time=0.0037s, SAE Backward Time=0.0333s
# Batch 208/66242: Recon Loss=0.1483, Sparsity Loss=0.0903, Model Forward Time=0.2066s, SAE Forward Time=0.0408s, Loss Calc Time=0.0036s, SAE Backward Time=0.0355s
# Batch 209/66242: Recon Loss=0.1470, Sparsity Loss=0.0885, Model Forward Time=0.2043s, SAE Forward Time=0.0416s, Loss Calc Time=0.0037s, SAE Backward Time=0.0352s
# Batch 210/66242: Recon Loss=0.1403, Sparsity Loss=0.0918, Model Forward Time=0.2090s, SAE Forward Time=0.0404s, Loss Calc Time=0.0056s, SAE Backward Time=0.0331s
# Batch 211/66242: Recon Loss=0.1436, Sparsity Loss=0.0932, Model Forward Time=0.2047s, SAE Forward Time=0.0361s, Loss Calc Time=0.0044s, SAE Backward Time=0.0332s
# Batch 212/66242: Recon Loss=0.1409, Sparsity Loss=0.0926, Model Forward Time=0.2018s, SAE Forward Time=0.0402s, Loss Calc Time=0.0067s, SAE Backward Time=0.0318s
# Batch 213/66242: Recon Loss=0.1460, Sparsity Loss=0.0903, Model Forward Time=0.2004s, SAE Forward Time=0.0394s, Loss Calc Time=0.0036s, SAE Backward Time=0.0340s
# Batch 214/66242: Recon Loss=0.1425, Sparsity Loss=0.0902, Model Forward Time=0.1993s, SAE Forward Time=0.0367s, Loss Calc Time=0.0039s, SAE Backward Time=0.0361s
# Batch 215/66242: Recon Loss=0.1493, Sparsity Loss=0.0940, Model Forward Time=0.2038s, SAE Forward Time=0.0395s, Loss Calc Time=0.0044s, SAE Backward Time=0.0358s
# Batch 216/66242: Recon Loss=0.1326, Sparsity Loss=0.0909, Model Forward Time=0.2087s, SAE Forward Time=0.0415s, Loss Calc Time=0.0039s, SAE Backward Time=0.0362s
# Batch 217/66242: Recon Loss=0.1483, Sparsity Loss=0.0910, Model Forward Time=0.2046s, SAE Forward Time=0.0379s, Loss Calc Time=0.0041s, SAE Backward Time=0.0338s
# Batch 218/66242: Recon Loss=0.1460, Sparsity Loss=0.0933, Model Forward Time=0.1998s, SAE Forward Time=0.0365s, Loss Calc Time=0.0043s, SAE Backward Time=0.0328s
# Batch 219/66242: Recon Loss=0.1420, Sparsity Loss=0.0880, Model Forward Time=0.2018s, SAE Forward Time=0.0385s, Loss Calc Time=0.0037s, SAE Backward Time=0.0346s
# Batch 220/66242: Recon Loss=0.1352, Sparsity Loss=0.0881, Model Forward Time=0.2001s, SAE Forward Time=0.0367s, Loss Calc Time=0.0049s, SAE Backward Time=0.0357s
# Batch 221/66242: Recon Loss=0.1491, Sparsity Loss=0.0888, Model Forward Time=0.2056s, SAE Forward Time=0.0366s, Loss Calc Time=0.0037s, SAE Backward Time=0.0342s
# Batch 222/66242: Recon Loss=0.1408, Sparsity Loss=0.0918, Model Forward Time=0.2057s, SAE Forward Time=0.0386s, Loss Calc Time=0.0040s, SAE Backward Time=0.0363s
# Batch 223/66242: Recon Loss=0.1432, Sparsity Loss=0.0890, Model Forward Time=1.8529s, SAE Forward Time=0.0410s, Loss Calc Time=0.0053s, SAE Backward Time=0.0396s
# Batch 224/66242: Recon Loss=0.1450, Sparsity Loss=0.0899, Model Forward Time=0.3425s, SAE Forward Time=0.0360s, Loss Calc Time=0.0045s, SAE Backward Time=0.0355s
# Batch 225/66242: Recon Loss=0.1383, Sparsity Loss=0.0914, Model Forward Time=0.2296s, SAE Forward Time=0.0395s, Loss Calc Time=0.0038s, SAE Backward Time=0.0350s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 50
#      47     sae_optimizer.step()
#      49 # Track and display batch losses and times
# ---> 50 cumulative_sae_recon_loss += sae_reconstruction_loss.item()
#      51 cumulative_sae_sparsity_loss += sae_sparsity_loss.item()
#      53 print(f"Batch {batch_idx + 1}/{len(train_loader)}: "
#      54       f"Recon Loss={sae_reconstruction_loss.item():.4f}, "
#      55       f"Sparsity Loss={sae_sparsity_loss.item():.4f}, "
#    (...)
#      58       f"Loss Calc Time={loss_calc_time:.4f}s, "
#      59       f"SAE Backward Time={sae_backward_time:.4f}s")
#
# KeyboardInterrupt:
